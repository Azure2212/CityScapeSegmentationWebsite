# %%
# !python train.py --model FCN --batch_size 16 --epochs 300 --image_size 224
# Out:
# ^C

# %%
import zipfile
import os

zip_path = "/data2/atran16/CityScapeSegmentationProject/archive.zip"
extract_path = "/data2/atran16/CityScapeSegmentationProject/datasets"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction complete!")
# Out:
# Extraction complete!
